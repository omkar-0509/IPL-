# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("Bowler.csv")

# %%
df.head()
# Out:
#        Player Name  Team  WKT  MAT  INN   OVR  RUNS   BBI    AVG   ECO     SR  \
# 0  Prasidh Krishna    GT   25   15   15  59.0   488  41/4  19.52  8.27  14.16
# 1       Noor Ahmad   CSK   24   14   14  50.0   408  18/4  17.00  8.16  12.50
# 2   Josh Hazlewood   RCB   22   12   12  44.0   386  33/4  17.54  8.77  12.00
# 3      Trent Boult    MI   22   16   16  57.4   517  26/4  23.50  8.96  15.72
# 4   Arshdeep Singh  PBKS   21   17   16  58.2   518  16/3  24.66  8.88  16.66
#
#    4W  5W
# 0   1   0
# 1   2   0
# 2   1   0
# 3   1   0
# 4   0   0

# %%
df.tail()
# Out:
#                   Player Name  Team  WKT  MAT  INN   OVR  RUNS   BBI    AVG  \
# 103            Marcus Stoinis  PBKS    1   13    9  14.1   175  14/1  175.0
# 104             Shahrukh Khan    GT    1   15    1   1.0    13  13/1   13.0
# 105  V Satyanarayana Penmetsa    MI    1    2    2   4.0    53  40/1   53.0
# 106              Musheer Khan  PBKS    1    1    1   2.0    27  27/1   27.0
# 107          Mujeeb-ur-Rahman    MI    1    1    1   2.0    28  28/1   28.0
#
#        ECO    SR  4W  5W
# 103  12.35  85.0   0   0
# 104  13.00   6.0   0   0
# 105  13.25  24.0   0   0
# 106  13.50  12.0   0   0
# 107  14.00  12.0   0   0

# %%
df.shape
# Out:
# (108, 13)

# %%
df.columns
# Out:
# Index(['Player Name', 'Team', 'WKT', 'MAT', 'INN', 'OVR', 'RUNS', 'BBI', 'AVG',
#        'ECO', 'SR', '4W', '5W'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 108 entries, 0 to 107
# Data columns (total 13 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Player Name  108 non-null    object
#  1   Team         108 non-null    object
#  2   WKT          108 non-null    int64
#  3   MAT          108 non-null    int64
#  4   INN          108 non-null    int64
#  5   OVR          108 non-null    float64
#  6   RUNS         108 non-null    int64
#  7   BBI          108 non-null    object
#  8   AVG          108 non-null    float64
#  9   ECO          108 non-null    float64
#  10  SR           108 non-null    float64
#  11  4W           108 non-null    int64
#  12  5W           108 non-null    int64
# dtypes: float64(4), int64(6), object(3)
# memory usage: 11.1+ KB

# %%
df.describe()
# Out:
#               WKT         MAT         INN         OVR        RUNS         AVG  \
# count  108.000000  108.000000  108.000000  108.000000  108.000000  108.000000
# mean     7.675926    8.444444    7.675926   24.727778  233.796296   40.108519
# std      6.294678    4.914851    4.767155   17.507130  155.708916   26.919800
# min      1.000000    1.000000    1.000000    1.000000   13.000000    6.500000
# 25%      2.000000    4.000000    3.750000   10.000000   98.750000   24.330000
# 50%      6.000000    9.000000    7.000000   19.500000  185.500000   31.830000
# 75%     12.250000   13.000000   12.000000   41.625000  376.750000   47.250000
# max     25.000000   17.000000   16.000000   59.000000  527.000000  175.000000
#
#               ECO          SR          4W          5W
# count  108.000000  108.000000  108.000000  108.000000
# mean     9.875093   23.820463    0.148148    0.018519
# std      1.592371   13.551808    0.428316    0.135445
# ...

# %%
df.isnull().sum()
# Out:
# Player Name    0
# Team           0
# WKT            0
# MAT            0
# INN            0
# OVR            0
# RUNS           0
# BBI            0
# AVG            0
# ECO            0
# SR             0
# 4W             0
# 5W             0
# dtype: int64

# %%
df.dropna
# Out:
# <bound method DataFrame.dropna of                   Player Name  Team  WKT  MAT  INN   OVR  RUNS   BBI     AVG  \
# 0             Prasidh Krishna    GT   25   15   15  59.0   488  41/4   19.52
# 1                  Noor Ahmad   CSK   24   14   14  50.0   408  18/4   17.00
# 2              Josh Hazlewood   RCB   22   12   12  44.0   386  33/4   17.54
# 3                 Trent Boult    MI   22   16   16  57.4   517  26/4   23.50
# 4              Arshdeep Singh  PBKS   21   17   16  58.2   518  16/3   24.66
# ..                        ...   ...  ...  ...  ...   ...   ...   ...     ...
# 103            Marcus Stoinis  PBKS    1   13    9  14.1   175  14/1  175.00
# 104             Shahrukh Khan    GT    1   15    1   1.0    13  13/1   13.00
# 105  V Satyanarayana Penmetsa    MI    1    2    2   4.0    53  40/1   53.00
# 106              Musheer Khan  PBKS    1    1    1   2.0    27  27/1   27.00
# 107          Mujeeb-ur-Rahman    MI    1    1    1   2.0    28  28/1   28.00
#
# ...

# %%
df.fillna(0)
# Out:
#                   Player Name  Team  WKT  MAT  INN   OVR  RUNS   BBI     AVG  \
# 0             Prasidh Krishna    GT   25   15   15  59.0   488  41/4   19.52
# 1                  Noor Ahmad   CSK   24   14   14  50.0   408  18/4   17.00
# 2              Josh Hazlewood   RCB   22   12   12  44.0   386  33/4   17.54
# 3                 Trent Boult    MI   22   16   16  57.4   517  26/4   23.50
# 4              Arshdeep Singh  PBKS   21   17   16  58.2   518  16/3   24.66
# ..                        ...   ...  ...  ...  ...   ...   ...   ...     ...
# 103            Marcus Stoinis  PBKS    1   13    9  14.1   175  14/1  175.00
# 104             Shahrukh Khan    GT    1   15    1   1.0    13  13/1   13.00
# 105  V Satyanarayana Penmetsa    MI    1    2    2   4.0    53  40/1   53.00
# 106              Musheer Khan  PBKS    1    1    1   2.0    27  27/1   27.00
# 107          Mujeeb-ur-Rahman    MI    1    1    1   2.0    28  28/1   28.00
#
#        ECO     SR  4W  5W
# ...

# %%
df.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 103    False
# 104    False
# 105    False
# 106    False
# 107    False
# Length: 108, dtype: bool

# %%
df.drop_duplicates()
# Out:
#                   Player Name  Team  WKT  MAT  INN   OVR  RUNS   BBI     AVG  \
# 0             Prasidh Krishna    GT   25   15   15  59.0   488  41/4   19.52
# 1                  Noor Ahmad   CSK   24   14   14  50.0   408  18/4   17.00
# 2              Josh Hazlewood   RCB   22   12   12  44.0   386  33/4   17.54
# 3                 Trent Boult    MI   22   16   16  57.4   517  26/4   23.50
# 4              Arshdeep Singh  PBKS   21   17   16  58.2   518  16/3   24.66
# ..                        ...   ...  ...  ...  ...   ...   ...   ...     ...
# 103            Marcus Stoinis  PBKS    1   13    9  14.1   175  14/1  175.00
# 104             Shahrukh Khan    GT    1   15    1   1.0    13  13/1   13.00
# 105  V Satyanarayana Penmetsa    MI    1    2    2   4.0    53  40/1   53.00
# 106              Musheer Khan  PBKS    1    1    1   2.0    27  27/1   27.00
# 107          Mujeeb-ur-Rahman    MI    1    1    1   2.0    28  28/1   28.00
#
#        ECO     SR  4W  5W
# ...

# %%
df[["Player Name", "RUNS"]]
# Out:
#                   Player Name  RUNS
# 0             Prasidh Krishna   488
# 1                  Noor Ahmad   408
# 2              Josh Hazlewood   386
# 3                 Trent Boult   517
# 4              Arshdeep Singh   518
# ..                        ...   ...
# 103            Marcus Stoinis   175
# 104             Shahrukh Khan    13
# 105  V Satyanarayana Penmetsa    53
# 106              Musheer Khan    27
# 107          Mujeeb-ur-Rahman    28
#
# [108 rows x 2 columns]

# %%
df["RUNS"]
# Out:
# 0      488
# 1      408
# 2      386
# 3      517
# 4      518
#       ...
# 103    175
# 104     13
# 105     53
# 106     27
# 107     28
# Name: RUNS, Length: 108, dtype: int64

# %%
df.loc[:, ["RUNS","SR"]]
# Out:
#      RUNS     SR
# 0     488  14.16
# 1     408  12.50
# 2     386  12.00
# 3     517  15.72
# 4     518  16.66
# ..    ...    ...
# 103   175  85.00
# 104    13   6.00
# 105    53  24.00
# 106    27  12.00
# 107    28  12.00
#
# [108 rows x 2 columns]

# %%
df.iloc[0:5]
# Out:
#        Player Name  Team  WKT  MAT  INN   OVR  RUNS   BBI    AVG   ECO     SR  \
# 0  Prasidh Krishna    GT   25   15   15  59.0   488  41/4  19.52  8.27  14.16
# 1       Noor Ahmad   CSK   24   14   14  50.0   408  18/4  17.00  8.16  12.50
# 2   Josh Hazlewood   RCB   22   12   12  44.0   386  33/4  17.54  8.77  12.00
# 3      Trent Boult    MI   22   16   16  57.4   517  26/4  23.50  8.96  15.72
# 4   Arshdeep Singh  PBKS   21   17   16  58.2   518  16/3  24.66  8.88  16.66
#
#    4W  5W
# 0   1   0
# 1   2   0
# 2   1   0
# 3   1   0
# 4   0   0

# %%
df[df["RUNS"] > 500]
# Out:
#        Player Name  Team  WKT  MAT  INN   OVR  RUNS   BBI    AVG   ECO     SR  \
# 3      Trent Boult    MI   22   16   16  57.4   517  26/4  23.50  8.96  15.72
# 4   Arshdeep Singh  PBKS   21   17   16  58.2   518  16/3  24.66  8.88  16.66
# 13  Mohammed Siraj    GT   16   15   15  57.0   527  17/4  32.93  9.24  21.37
# 39     Rashid Khan    GT    9   15   15  55.0   514  25/2  57.11  9.34  36.66
#
#     4W  5W
# 3    1   0
# 4    0   0
# 13   1   0
# 39   0   0

# %%
df[df["Team"] == "RCB"]
# Out:
#           Player Name Team  WKT  MAT  INN   OVR  RUNS   BBI    AVG    ECO  \
# 2      Josh Hazlewood  RCB   22   12   12  44.0   386  33/4  17.54   8.77
# 8       Krunal Pandya  RCB   17   15   15  46.0   379  45/4  22.29   8.23
# 9   Bhuvneshwar Kumar  RCB   17   14   14  52.0   483  33/3  28.41   9.28
# 23         Yash Dayal  RCB   13   15   15  49.0   470  18/2  36.15   9.59
# 44      Suyash Sharma  RCB    8   14   14  50.0   442  17/3  55.25   8.84
# 54   Romario Shepherd  RCB    6    8    7  14.0   151  14/2  25.16  10.78
# 65    Lungisani Ngidi  RCB    4    2    2   8.0    81  30/3  20.25  10.12
# 75   Liam Livingstone  RCB    2   10    5   9.0    76  28/2  38.00   8.44
# 88     Nuwan Thushara  RCB    1    1    1   4.0    26  26/1  26.00   6.50
# 97         Rasikh Dar  RCB    1    2    2   6.0    70  35/1  70.00  11.66
#
#        SR  4W  5W
# 2   12.00   1   0
# 8   16.23   1   0
# 9   18.35   0   0
# 23  22.61   0   0
# 44  37.50   0   0
# 54  14.00   0   0
# ...

# %%
df[(df["RUNS"] > 500) & (df["SR"] > 150)]
# Out:
# Empty DataFrame
# Columns: [Player Name, Team, WKT, MAT, INN, OVR, RUNS, BBI, AVG, ECO, SR, 4W, 5W]
# Index: []

# %%
df.sort_values("RUNS")
# Out:
#          Player Name  Team  WKT  MAT  INN   OVR  RUNS    BBI    AVG    ECO  \
# 104    Shahrukh Khan    GT    1   15    1   1.0    13   13/1  13.00  13.00
# 74      Ayush Badoni   LSG    2   14    2   1.4    13  2-Apr   6.50   7.80
# 93      Pravin Dubey  PBKS    1    1    1   2.0    20   20/1  20.00  10.00
# 88    Nuwan Thushara   RCB    1    1    1   4.0    26   26/1  26.00   6.50
# 106     Musheer Khan  PBKS    1    1    1   2.0    27   27/1  27.00  13.50
# ..               ...   ...  ...  ...  ...   ...   ...    ...    ...    ...
# 0    Prasidh Krishna    GT   25   15   15  59.0   488   41/4  19.52   8.27
# 39       Rashid Khan    GT    9   15   15  55.0   514   25/2  57.11   9.34
# 3        Trent Boult    MI   22   16   16  57.4   517   26/4  23.50   8.96
# 4     Arshdeep Singh  PBKS   21   17   16  58.2   518   16/3  24.66   8.88
# 13    Mohammed Siraj    GT   16   15   15  57.0   527   17/4  32.93   9.24
#
#         SR  4W  5W
# 104   6.00   0   0
# 74    5.00   0   0
# ...

# %%
df.sort_values("RUNS", ascending=False)
# Out:
#          Player Name  Team  WKT  MAT  INN   OVR  RUNS    BBI    AVG    ECO  \
# 13    Mohammed Siraj    GT   16   15   15  57.0   527   17/4  32.93   9.24
# 4     Arshdeep Singh  PBKS   21   17   16  58.2   518   16/3  24.66   8.88
# 3        Trent Boult    MI   22   16   16  57.4   517   26/4  23.50   8.96
# 39       Rashid Khan    GT    9   15   15  55.0   514   25/2  57.11   9.34
# 0    Prasidh Krishna    GT   25   15   15  59.0   488   41/4  19.52   8.27
# ..               ...   ...  ...  ...  ...   ...   ...    ...    ...    ...
# 106     Musheer Khan  PBKS    1    1    1   2.0    27   27/1  27.00  13.50
# 88    Nuwan Thushara   RCB    1    1    1   4.0    26   26/1  26.00   6.50
# 93      Pravin Dubey  PBKS    1    1    1   2.0    20   20/1  20.00  10.00
# 74      Ayush Badoni   LSG    2   14    2   1.4    13  2-Apr   6.50   7.80
# 104    Shahrukh Khan    GT    1   15    1   1.0    13   13/1  13.00  13.00
#
#         SR  4W  5W
# 13   21.37   1   0
# 4    16.66   0   0
# ...

# %%
df.groupby("Team")["RUNS"].sum()
# Out:
# Team
# CSK     2300
# DC      2294
# GT      2790
# KKR     2208
# LSG     2761
# MI      2628
# PBKS    2790
# RCB     2564
# RR      2512
# SRH     2403
# Name: RUNS, dtype: int64

# %%
df.groupby("Team")["RUNS"].mean()
# Out:
# Team
# CSK     255.555556
# DC      286.750000
# GT      253.636364
# KKR     245.333333
# LSG     212.384615
# MI      202.153846
# PBKS    199.285714
# RCB     256.400000
# RR      251.200000
# SRH     218.454545
# Name: RUNS, dtype: float64

# %%
df.groupby("Team")["RUNS"].count()
# Out:
# Team
# CSK      9
# DC       8
# GT      11
# KKR      9
# LSG     13
# MI      13
# PBKS    14
# RCB     10
# RR      10
# SRH     11
# Name: RUNS, dtype: int64

# %%
df["Boundaries"] = df["WKT"] + df["MAT"]

# %%
np.mean(df["RUNS"])
# Out:
# np.float64(233.7962962962963)

# %%
np.median(df["RUNS"])
# Out:
# np.float64(185.5)

# %%
np.std(df["RUNS"])
# Out:
# 154.98636494742337

# %%
np.max(df["RUNS"])
# Out:
# 527

# %%
np.min(df["RUNS"])
# Out:
# 13

# %%
plt.figure(figsize=(18,6))
plt.bar(df["Player Name"], df["RUNS"])
# Out:
# <BarContainer object of 108 artists>

# %%
plt.figure(figsize=(18,6))
plt.plot(df["RUNS"])

# %%
plt.figure(figsize=(18,6))
plt.hist(df["RUNS"])
# Out:
# (array([15., 20., 13., 10.,  5.,  5., 11., 11., 11.,  7.]),
#  array([ 13. ,  64.4, 115.8, 167.2, 218.6, 270. , 321.4, 372.8, 424.2,
#         475.6, 527. ]),
#  <BarContainer object of 10 artists>)

# %%
plt.figure(figsize=(18,6))
plt.scatter(df["RUNS"], df["SR"])

# %%
plt.figure(figsize=(18,6))
plt.pie(df.groupby("Team")["RUNS"].sum())
# Out:
# ([<matplotlib.patches.Wedge at 0x3111f8a50>,
# ...
#  [Text(1.0552668356914299, 0.3105026658336397, ''),
#   Text(0.7195566452331129, 0.8320085542233736, ''),
#   Text(0.0884536991582693, 1.096437842791473, ''),
#   Text(-0.5668221460441105, 0.9427155746851482, ''),
#   Text(-1.0083032021507552, 0.43968699381779947, ''),
#   Text(-1.0632294016664545, -0.28203411040509524, ''),
#   Text(-0.6546197392260178, -0.8840096136443656, ''),
#   Text(0.031611156227091944, -1.0995456947312316, ''),
#   Text(0.6746844647394911, -0.8687927676029461, ''),
#   Text(1.0512011451585732, -0.3240002352118042, '')])

# %%
plt.figure(figsize=(16,8))
sns.barplot(x="Team", y="RUNS", data=df)
# Out:
# <Axes: xlabel='Team', ylabel='RUNS'>

# %%
plt.figure(figsize=(16,8))
sns.lineplot(x="MAT", y="RUNS", data=df)
# Out:
# <Axes: xlabel='MAT', ylabel='RUNS'>

# %%
plt.figure(figsize=(16,8))
sns.histplot(df["RUNS"])
# Out:
# <Axes: xlabel='RUNS', ylabel='Count'>

# %%
plt.figure(figsize=(16,8))
sns.boxplot(x="Team", y="RUNS", data=df)
# Out:
# <Axes: xlabel='Team', ylabel='RUNS'>

# %%
plt.figure(figsize=(16,8))
sns.violinplot(x="Team", y="RUNS", data=df)
# Out:
# <Axes: xlabel='Team', ylabel='RUNS'>

# %%
plt.figure(figsize=(16,8))
sns.scatterplot(x="RUNS", y="SR", data=df)
# Out:
# <Axes: xlabel='RUNS', ylabel='SR'>

# %%
df.sort_values("RUNS", ascending=False)
# Out:
#          Player Name  Team  WKT  MAT  INN   OVR  RUNS    BBI    AVG    ECO  \
# 13    Mohammed Siraj    GT   16   15   15  57.0   527   17/4  32.93   9.24
# 4     Arshdeep Singh  PBKS   21   17   16  58.2   518   16/3  24.66   8.88
# 3        Trent Boult    MI   22   16   16  57.4   517   26/4  23.50   8.96
# 39       Rashid Khan    GT    9   15   15  55.0   514   25/2  57.11   9.34
# 0    Prasidh Krishna    GT   25   15   15  59.0   488   41/4  19.52   8.27
# ..               ...   ...  ...  ...  ...   ...   ...    ...    ...    ...
# 106     Musheer Khan  PBKS    1    1    1   2.0    27   27/1  27.00  13.50
# 88    Nuwan Thushara   RCB    1    1    1   4.0    26   26/1  26.00   6.50
# 93      Pravin Dubey  PBKS    1    1    1   2.0    20   20/1  20.00  10.00
# 74      Ayush Badoni   LSG    2   14    2   1.4    13  2-Apr   6.50   7.80
# 104    Shahrukh Khan    GT    1   15    1   1.0    13   13/1  13.00  13.00
#
#         SR  4W  5W  Boundaries
# 13   21.37   1   0          31
# ...

# %%
df.groupby("Team")["RUNS"].sum()
# Out:
# Team
# CSK     2300
# DC      2294
# GT      2790
# KKR     2208
# LSG     2761
# MI      2628
# PBKS    2790
# RCB     2564
# RR      2512
# SRH     2403
# Name: RUNS, dtype: int64

# %%
df.sort_values("SR", ascending=False)
# Out:
#           Player Name  Team  WKT  MAT  INN   OVR  RUNS    BBI     AVG    ECO  \
# 103    Marcus Stoinis  PBKS    1   13    9  14.1   175   14/1  175.00  12.35
# 82       Mohit Sharma    DC    2    8    8  25.0   257  1-Oct  128.50  10.28
# 95         Sam Curran   CSK    1    5    5  12.0   133   34/1  133.00  11.08
# 98    Spencer Johnson   KKR    1    4    4  11.2   133   42/1  133.00  11.73
# 101     Shahbaz Ahmed   LSG    1    3    3   8.3   102   41/1  102.00  12.00
# ..                ...   ...  ...  ...  ...   ...   ...    ...     ...    ...
# 59        Harsh Dubey   SRH    5    3    3  10.0    98   34/3   19.60   9.80
# 35      Ashwani Kumar    MI   11    7    7  20.3   232   24/4   21.09  11.31
# 56   William O Rourke   LSG    6    3    3  10.2   132   27/3   22.00  12.77
# 104     Shahrukh Khan    GT    1   15    1   1.0    13   13/1   13.00  13.00
# 74       Ayush Badoni   LSG    2   14    2   1.4    13  2-Apr    6.50   7.80
#
#         SR  4W  5W  Boundaries
# ...

# %%
df["MAT"] + df["WKT"] + df["OVR"]
# Out:
# 0      99.0
# 1      88.0
# 2      78.0
# 3      95.4
# 4      96.2
#        ...
# 103    28.1
# 104    17.0
# 105     7.0
# 106     4.0
# 107     4.0
# Length: 108, dtype: float64

# %%
corr = df.corr(numeric_only=True)
plt.figure(figsize=(10,6))
sns.heatmap(corr, annot=True, cmap="coolwarm")
plt.title("Correlation Heatmap")
plt.show()
